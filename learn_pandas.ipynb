# %%
import pandas as pd
data = {
    'Brand' : ['Toyota','Honda','Audi','BMW'],
    'HP' : [150,180,250,220],
    'Prices ($)' : [2500, 27000, 50000, 78000]
}
df =pd.DataFrame(data)
print("The shape of data frame:",df.shape)
# Out:
# The shape of data frame: (4, 3)

# %%
print("A list of columns in table:")
print(df.columns)
# Out:
# A list of columns in table:
# Index(['Brand', 'HP', 'Prices ($)'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Brand         object
# HP             int64
# Prices ($)     int64
# dtype: object

# %%
print(df['HP'])
# Out:
# 0    150
# 1    180
# 2    250
# 3    220
# Name: HP, dtype: int64

# %%
powerful_cars = df[df['HP'] > 200]
print(powerful_cars)
print("Amount of powerful cars", powerful_cars.shape[0])
# Out:
#   Brand   HP  Prices ($)
# 2  Audi  250       50000
# 3   BMW  220       78000
# Amount of powerful cars 2
